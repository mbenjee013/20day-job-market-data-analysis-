# %%
import pandas as pd

# %% [markdown]
# Day 1
# 1. Created a dataframe---> df
# 2. Remove unnecessary columns---> id, closing_date, expire_status, author, key_words and newsletter
# 3. Drop duplicates---> which reduced the total number of jobs to 1522
# 4. rename columns---> mode=employment type, post=description and category=industry

# %%
df = pd.read_csv('pezantchito_dataset.csv')
df.drop(columns=['id', 'closing_date', 'expire_status', 'author', 'key_words', 'newsletter'], inplace=True)
df.drop_duplicates(inplace=True)
df.rename(columns={"mode":"employment type", "post":"description", "category":"industry"}, inplace=True)

# %% [markdown]
# Day 2
# 1. Coverted all values to string and lowercase
# 2. Created a mapping dictionary to clean inconsistencies
# 3. Replced messy values with standardised employment types
# 4. Come up with 12 unique employment types

# %%
uniqueEmploymentType={
    "-----":"undefined", "----":"undefined", "--":"undefined", "---":"undefined",
    "full-time (monday-friday)":"fulltime", "full time":"fulltime", "full-time":"fulltime",
    "intern":"internship", "internship(paid)":"internship","volunteer":"voluntary","short-term":"shortterm",
    "contract (renewal)":"contract", "contract based":"contract", 
    "contract(1yr)":"contract", "contract(2yrs)":"contract", "contract(12 month)":"contract",
    "contract(4yrs)":"contract", "contract(renewable)":"contract", "contract(2 years)":"contract",
    "contract(3 years)":"contract", "contract (1yr)":"contract", "contract(6 months)":"contract", 
    "contract(3yrs)":"contract", "contract (renewal), full-time (38 hours 45 minutes/week).":"contract",
    "part time":"parttime", "part-time":"parttime", "full+part time":"parttime","fixed-term / permanent":"permanent",
    "temporary (6 months)":"temporary", "temporally":"temporary","temporary contract":"temporary",
    "fixed term":"fixedterm", "fixed-term":"fixedterm", "fixed contract":"fixedterm",
    "fixed term contract (8 months)":"fixedterm","fixed term contract(12 months)":"fixedterm",
    "commission-based":"commission based", "commission":"commission based"
}
df['employment type']=df['employment type'].str.lower().replace(uniqueEmploymentType)

# %% [markdown]
# Day 3
# 1. converted all locations to lowercase
# 2. created a mapping dictionary to standardise values
# 3. grouped similar locations into clean, consistent categries
# 4. handled jobs with multiple locations

# %%
df['location'] = df['location'].str.lower()
uniqueLocations = {
    #lilongwe
    "lilongwe, area 6":"lilongwe", "kimya house, mphonongo, street area 43, lilongwe":"lilongwe", 
    "lilongwe/ northern region":"lilongwe", "lilongwe | kanengo":"lilongwe", "kanengo":"lilongwe", "lilongwe, malawi":"lilongwe",
    "griffin saenda sports complex":"lilongwe", "area 47, lilongwe":"lilongwe", "lilongwe, area 47, sector 3":"lilongwe", "kanengo, lilongwe":"lilongwe",
    "lilongwe,malawi":"lilongwe", "namitete":"lilongwe", "lilongwe, area 49":"lilongwe", "lilongwe, lilongwe":"lilongwe",
    "lilongwe., malawi":"lilongwe", "kanengo, malawi":"lilongwe", "lilongwe, malawi limited":"lilongwe", "kanengo, lilongwe,  malawi":"lilongwe",
    "lilongwe,  malawi":"lilongwe", "chitedze, lilongwe, malawi":"lilongwe", "kasiya":"lilongwe", "pacific tower, 3rd floor ffa01/1":"lilongwe",
    "mitundu":"lilongwe", "ministry of trade and industry(headquarters)":"lilongwe",
    #blantyre
    "blantyre, lumbadzi":"blantyre", "blantyre, limbe":"blantyre", "head-office, blantyre":"blantyre",
    "nyambadwe,blantyre":"blantyre", "blantyre, mapanga, along chiradzulu road":"blantyre", "blantyre, malawi":"blantyre",
    "jana village, t/a somba":"blantyre", "chileka international airport, blantyre":"blantyre", "lunzu, blantyre":"blantyre",
    "mbc offices":"blantyre", "chilomoni, blantyre":"blantyre", "amaryllis hotel, blantyre, malawi":"blantyre",
    "mapanga workshop":"blantyre",
    #mzuzu
    "dunduzu, mzuzu":"mzuzu", "mzuzu, malawi":"mzuzu",
    #lilongweBlantyreMzuzu
    "blantyre, lilongwe & mzuzu":"lilongwe, blantyre & mzuzu", "blantyre | lilongwe | mzuzu":"lilongwe, blantyre & mzuzu",
    "mzuzu, lilongwe & blantyre":"lilongwe, blantyre & mzuzu", "lilongwe | blantyre | mzuzu":"lilongwe, blantyre & mzuzu",
    #zomba
    "zomba, malawi":"zomba",
    #lilongweBlantyre
    "blantyre & lilongwe":"lilongwe & blantyre", "blantyre, lilongwe, other towns":"lilongwe & blantyre", "blantyre, lilongwe":"lilongwe & blantyre",
    "blantyre & lilongwe campuses":"lilongwe & blantyre", "lilongwe & blantyre, malawi":"lilongwe & blantyre", "lilongwe | blantyre":"lilongwe & blantyre",
    "lilongwe and blantyre":"lilongwe & blantyre", "lilongwe, blantyre":"lilongwe & blantyre",
    #lilongweBlantyreMzuzuZomba
    "lilongwe | zomba":"lilongwe, blantyre, mzuzu & zomba", "mzuzu | lilongwe | blantyre | zomba, malawi":"lilongwe, blantyre, mzuzu & zomba",
    "mzuzu, limbe, zomba & lilongwe":"lilongwe, blantyre, mzuzu & zomba", "blantyre | lilongwe | zomba | mzuzu":"lilongwe, blantyre, mzuzu & zomba", 
    "lilongwe, blantyre, zomba & mzuzu":"lilongwe, blantyre, mzuzu & zomba",
    # lilongweZomba
    "lilongwe | zomba":"lilongwe & zomba", "lilongwe or zomba, malawi":"lilongwe & zomba",
    #mzimba
    "chikangawa":"mzimba", "ekwendeni, mzimba":"mzimba", "ekwendeni":"mzimba", "luzi":"mzimba","mzimba, malawi":"mzimba",
    #nkhotakota
    "dwangwa, malawi":"nkhotakota", "dwangwa":"nkhotakota", "dwangwa, nkhotakota":"nkhotakota",
    "benga, nkhotakota":"nkhotakota", "benga":"nkhotakota", "nkhotakota, malawi":"nkhotakota",
    #chikwawa
    "nchalo":"chikwawa", "chikwawa, malawi":"chikwawa", "majete":"chikwawa", "kapichira power station, malawi":"chikwawa",
    # nkhotakotaChikwawa
    "dwangwa, nchalo":"nkhotakota & chikwawa","nchalo, dwangwa":"nkhotakota & chikwawa",
    #dowa
    "madisi, dowa":"dowa", "mponela, dowa":"dowa", "dowa, malawi":"dowa", "mponela, dowa, malawi":"dowa",
    #mangochi
    "magu campus":"mangochi", "mangochi, malawi":"mangochi", "monkey-bay":"mangochi",
    #nkhatabay
    "nkhatabay, malawi":"nkhatabay", "nthatabay, malawi":"nkhatabay", "nkhata-bay, malawi":"nkhatabay",
    #thyolo
    "bvumbwe":"thyolo", "thyolo, malawi":"thyolo", "macadamia factory":"thyolo",
    #mchinji
    "mchinji, malawi":"mchinji", "ntchinji, malawi":"mchinji", "nchinji, malawi":"mchinji",
    #ntcheu
    "mau campuses in malawi":"ntcheu", "ntcheu, malawi":"ntcheu",
    #likoma
    "likoma | chizumulu stations":"likoma", "likoma, malawi":"likoma",
    #other
    "neno boma":"neno", "zalewa":"neno", "neno, malawi":"neno","salima, malawi":"salima","rumphi, malawi":"rumphi",
    "mwanza district counci":"mwanza", "mwanza, malawi":"mwanza","lujeru":"mulanje","karonga, malawi":"karonga",
    "phalombe, malawi":"phalombe","kasungu, malawi":"kasungu","chiradzulu, malawi":"chiradzulu","nsanje, malawi":"nsanje", "ngabu":"nsanje",
    "chitipa, malawi":"chitipa","mulanje, malawi":"mulanje","liwonde":"machinga", "machinga, malawi":"machinga",
    "balaka, malawi":"balaka", "ntchisi, malawi":"ntchisi","dedza, malawi":"dedza","lilongwe, blantyre, and zomba campuses":"lilongwe, blantyre & zomba",
    "lilongwe | nchalo | dwangwa":"lilongwe & chikwawa","mzuzu | rumphi":"mzuzu & rumphi","dowa, mponela & nkhotakota, malawi":"dowa & nkhotakota", "mponela | nkhotakota, malawi":"dowa & nkhotakota",
    "kanjedza & zomba":"blantyre & zomba", "blantyre | karonga":"blantyre & karonga", "salima | lilongwe":"lilongwe & salima",
    "balaka | lilongwe, malawi":"lilongwe & balaka", "karonga & lilongwe, malawi":"lilongwe & karonga", "zomba & mzuzu, malawi":"mzuzu & zomba",
    "mulanje and mzuzu":"mzuzu & mulanje", "karonga and kasungu":"karonga & kasungu", "liwonde, balaka, malawi":"machinga & balaka",
    "chikwawa/nsanje malawi":"chikwawa & nsanje","blantyre & mwanza, malawi":"blantyre & mwanza","bwengu & blantyre west":"blantyre & rumphi",
    "blantyre & mzuzu, malawi":"blantyre & mzuzu", "mzuzu, blantyre":"blantyre & mzuzu", "machinga & blantyre malawi":"blantyre & machinga",
    "mzuzu & lilongwe, malawi":"lilongwe & mzuzu", "zomba | chiradzulu | chikwawa in malawi":"zomba, chikwawa & chiradzulu", 
    "blantyre east, dedza, and kasungu":"blantyre, dedza & kasungu","machinga, zomba and phalombe":"zomba, machinga & phalombe",
    "mulanje | balaka | lilongwe | karonga":"lilongwe, karonga, mulanje & balaka", "rumphi | mangochi | ntchisi | lilongwe,":"lilongwe, mangochi, rumphi & ntchisi",
    "chitipa, mwanza, nkhatabay and kabwafu in mzimba":"mzimba, nkhatabay chitipa & mwanza",
    # malawi
    "various districts in malawi":"malawi", "multiple locations":"malawi", "central, southern and northern regions":"malawi",
    "all regions":"malawi", "all councils":"malawi", "various places":"malawi", "various districts":"malawi", "the inland waters of malawi":"malawi",
    "north, centre, and south":"malawi", "various district":"malawi", "contract(1yr)":"malawi", "contract":"malawi", "various areas":"malawi",
    "malawi based":"malawi", "remote/malawi":"malawi", "various schools in malawi":"malawi", "malawi cities":"malawi", "various places in malawi":"malawi",
    "malawi (head office)":"malawi", "several places":"malawi",
    #africa
    "harare, zimbabwe":"africa", "within sub-saharan africa":"africa", "southern africa region":"africa"
}
df['location'] = df['location'].replace(uniqueLocations)

# %% [markdown]
# day 4 and 5
# 1. converted company names to a consistent format
# 2. created a mapping dictionary to standardise duplicate company names
# 3. Grouped subsidiaries and brand variations together
# 4. Removed undefined and misleading entries+

# %%
df['company'] = df['company'].str.lower()

uniqueCompany = {"company name":"undefined", "(in lilongwe)":"undefined", "a fast growing construction company":"undefined",
    "employer: upon shortlisted (confidential)":"undefined", "vacancies in lilongwe and blantyre":"undefined", "vacancy in blantyre":"undefined",
    "vacancy in nkhotakota":"undefined","national bank of malawi plc":"national bank","african parks (ap)":"african parks", "african parks(ap)":"african parks",
    "agri value chain ltd":"agri value chain limited","agricultural research & extension trust (aret)":"agricultural research & extension trust", 
    "agricultural research and extension trust (aret)":"agricultural research & extension trust", "the agricultural research and extension trust":"agricultural research & extension trust",
    "airtel malawi plc":"airtel malawi", "alwayn consulting group":"alwayn consulting group limited", "ambali poultry farm":"ambali farms",
    "asamala health services":"asamala health centre","astria learning limited":"astria learning", "astria learning limited (unima e-campus)":"astria learning",
    "astria learning limited ( unima e-campus)":"astria learning","bambino international schools":"bambino international school","banja la mtsogolo (blm)":"banja la mtsogolo",
    "baylor college of medicine children's":"baylor college of medicine children’s foundation", 
    "baylor college of medicine children’s foundation-malawi":"baylor college of medicine children’s foundation",
    "baylor college of medicine children’s foundation- malawi":"baylor college of medicine children’s foundation","bespat holdings limited":"bespat", "bespat human capital management":"bespat",
    "ccap blantyre synod":"ccap", "ccap nkhoma synod":"ccap", "ccap synod of livingstonia-health department":"ccap", 
    "ccap nkhoma synod education department":"ccap", "st columba ccap":"ccap", "st columba ccap private primary school":"ccap","cdh investment bank limited":"cdh investment bank",
    "ck cold storage limited":"ck storage limited","capricorn lodges":"capricorn lodge","castel malawi limited":"castel malawi", "castle malawi limited":"castel malawi",
    "cement products limited (cpl)":"cement products limited", "cement products limited (cpl)":"cement products limited","central poultry (cp)":"central poultry limited", 
    "central poultry (2000) limited":"central poultry limited","central poultry malawi":"central poultry limited","china railway 20 bureau group corporation mw ltd":"china railway 20 bureau group corporation",
    "coca-cola beverages africa":"coca-cola beverages malawi limited","credit data":"credit data crb limited", "credit data crb limited malawi":"credit data crb limited",
    "crossroads hotels":"crossroads hotel", "crossroads hotels blantyre":"crossroads hotel","dailysun":"dailysun limited",
    "dapp":"development aid from people to people", "dapp":"development aid from people to people (dapp)",
    "escom":"escom ltd", "electricity supply corporation of malawi (escom) limited":"escom ltd", "kasungu escom":"escom ltd",
    "ntchisi escom":"escom ltd", "salima escom":"escom ltd","eris properties (mw) limited":"eris properties malawi ltd","family health services (fhs)":"family health services",
    "federations of disability organisations in malawi":"federation of disability organisations in malawi", "first capital bank plc":"first capital bank",
    "giz malawi":"giz", "gardaworld":"garda world limited", "gardaworld limited":"garda world limited","global health informatics institute (ghii)": "global health informatics institute",
    "habitat for humanity": "habitat for humanity malawi","harvestglow": "harvest glow","holy family mission hospital": "holy family", "holy family secondary school": "holy family",
    "illovo sugar (malawi) plc": "illovo sugar", "illovo sugar malawi": "illovo sugar", "illovo sugar plc": "illovo sugar","imagine worldwide ltd": "imagine worldwide",
    "innovation for poverty action": "innovations for poverty action", "innovations for poverty action (ipa)": "innovations for poverty action",
    "inter aide malawi": "inter aide", "inter aide began maintenance projects": "inter aide","jti (japan tobacco international)": "japan tobacco international", 
    "jti": "japan tobacco international","kamuzu university of health sciences (kuhes)": "kamuzu university of health sciences", "the kamuzu university of health science": "kamuzu university of health sciences",
    "lifeco pension services company": "lifeco holdings limited","lilongwe pentecostal church christian school (lpccs)": "lilongwe pentecostal church christian school","lilongwe wildlife centre": "lilongwe wildlife", 
    "lilongwe wildlife trust": "lilongwe wildlife","lindian resources": "lindian resource ltd","liwiro microcredit limited": "liwiro finance limited","mbl holdings limited": "mbl group of companies",
    "malawi aids counselling and resource organization (macro)": "malawi aids counselling and resource organization","malawi assemblies of god university- medical scheme": "malawi assemblies of god university",
    "malawi revenue authority (mra)": "malawi revenue authority", "mra": "malawi revenue authority", "malawi prison service": "malawi prison services",
    "malawi research  & education network": "malawi research & education network", "malawi research and education network": "malawi research & education network",
    "malawi research and education network(maren)": "malawi research & education network","malawi-liverpool-wellcome programme (mlw)": "malawi-liverpool-wellcome programme", 
    "malawi-liverpool-wellcome research programme": "malawi-liverpool-wellcome programme","malawi–liverpool–wellcome programme (mlw)": "malawi-liverpool-wellcome programme", 
    "the malawi-liverpool-wellcome research programme (mlw)": "malawi-liverpool-wellcome programme",
    "the malawi-liverpool-wellcome programme (mlw)": "malawi-liverpool-wellcome programme", "the malawi-liverpool-wellcome programme": "malawi-liverpool-wellcome programme",
    "masters finance ltd": "masters finance limited","medecins sans frontiers (msf)": "medecins sans frontiers","microloan foundation(malawi) limited": "microloan foundation (malawi) limited",
    "ministry of health": "ministry of health and sanitation","ministry of home land and security": "ministry of homeland security","mount meru millers malawi limited": "meru", "mount meru group": "meru",
    "mwaiwathu private hospital limited": "mwaiwathu private hospital", "mwayiwathu private hospital": "mwaiwathu private hospital",
    "mwayiwathu private hospital limited": "mwaiwathu private hospital","mzuni sacco": "mzuzu university","nbs bank plc": "nbs bank", "nbs plc": "nbs bank",
    "nico holdings plc": "nico", "nico life": "nico", "nico pension": "nico", "nico general": "nico", "nico asset managers": "nico","national local government finance committee": "national local government", 
    "ndi moyo palliative care trust": "ndi moyo", "new era schools": "new era school", "office of the registrar of political parties (orpp)": "office of the registrar of political parties", 
    "old mutual limited": "old mutual", "pbm construction company limited": "pbm group", "pbm construction": "pbm group","pact secondary schools": "pact secondary school", "partners in hope (pih)": "partners in hope", 
    "pharmanova limited": "pharmanova malawi limited", "pioneer construction ltd": "pioneer construction limited", "portland cement malawi limite": "portland cement malawi", 
    "public private partnership commission (pppc)": "public private partnership commission", "rab processors ltd": "rab processors limited", "rays of hope": "rays of hope ministries","sdk engineering limited": "sdk holdings limited", 
    "sable farming company ltd": "sable farming company limited", "saint john of god hospitaller services malawi": "saint john of god hospitaller services", "seed-co": "seed co malawi limited", 
    "shayona cement": "shayona cement corporation", "simbeko investments (s.i)": "simbeko investments", "smile life insurance company limited": "smile life", "speed courier and logistics": "speed courier & logistics", 
    "st john of hospitaller service": "st john of god hospitaller services", "st. john of god hospitaller services": "st john of god hospitaller services","st. john's hospital": "st. john's mission hospital", 
    "swift digital finance dbv ltd": "swift digital finance ltd", "swift capital insurance brokers limited": "swift digital finance ltd","swift capital insurance": "swift digital finance ltd",
    "swift capital growth partners limited": "swift digital finance ltd","sunbird tourism plc": "sunbird hotel", "sunbird hotel & resort": "sunbird hotel","telekom networks malawi (tnm)": "tnm", "telekom networks malawi plc": "tnm", 
    "telekom networks malawi(tnm)": "tnm", "telekom networks malawi plc (tnm)": "tnm","the northern region water board": "northern region water board", "the northern region water board (nrwb)": "northern region water board",
    "the times group ltd": "times group", "the times group": "times group", "times group limited": "times group","tiderise technologies": "tiderise", "unik construction engineering": "unik construction limited", 
    "unik construction engineering ltd": "unik construction limited","united civil sacco": "united civil servants sacco", "unitrans malawi ltd": "unitrans malawi limited", "vacancy at goodvisionglasses": "goodvisionglasses", 
    "vacancy at limbe leaf tobacco company limited": "limbe leaf tobacco company limited", "vacancy at reunion insurance company ltd": "reunion insurance company ltd", "vanguard pension services company": "vanguard life assurance company limited", 
    "visionfund malawi": "visionfund", "wilson and wilsons business college": "wilson & wilsons business college", 
}

df['company'] = df['company'].replace(uniqueCompany)

# %%
posi = df['position'].str.lower()

undefined = {"23 positions":"undefined", "9 positions":"undefined", "multiple positions":"undefined", "multiple vacancies":"undefined",
    "several vacancies":"undefined", "various positions":"undefined", "various vacancies":"undefined", "kamuzu academy":"undefined",
    "positions various":"undefined","various positions i.e lectures...":"undefined",
} 
posi.replace(undefined, inplace=True)

abattoir = {"abattoir senior supervisor":"abattoir supervisor"}
posi.replace(abattoir, inplace=True)

AssAccountant = {"3 assistant accountant":"assistant accountant","senior assistant accountant":"assistant accountant"}
posi.replace(AssAccountant, inplace=True)

AssMan = {"assistant manager (production)":"assistant manager"}
posi.replace(AssMan, inplace=True) 

accounts = {"accounts intern":"accounts","school account":"accounts"} 
posi.replace(accounts, inplace=True)

accountant = {"cost accountant":"accountant","accountant - bureau de change":"accountant","senior accountant":"accountant","financial accountant":"accountant",
    "group management accountant":"accountant","junior accountant":"accountant","office accountant":"accountant","project accountant":"accountant",
} 
posi.replace(accountant, inplace=True)


administration = {"administration assistan":"administrative assistant","administrative assistant (grade s3- s1)":"administrative assistant","administrative assistant (2)":"administrative assistant",
    "administrative assistants":"administrative assistant","senior administrative assistant":"administrative assistant"
} 

posi.replace(administration, inplace=True) 

AssHumanRes = {"assistant human resource office":"assistant human resource officer","assistant human resources officer":"assistant human resource officer",
    "assistant human resource officers":"assistant human resource officer","human resource assistant":"assistant human resource officer",
    "hr assistant":"assistant human resource officer"
} 
posi.replace(AssHumanRes, inplace=True)

debt = {"debt collection officer":"debit collector","debt collectors":"debit collector"}
posi.replace(debt, inplace=True)

branch = {"branch managers":"branch manager"} 
posi.replace(branch, inplace=True) 

cooks = {"2 cooks":"cook"}
posi.replace(cooks, inplace=True)

call = {"call centre agents":"call centre agent"}
posi.replace(call, inplace=True)

chief = {"chief executive officer-designate":"chief executive officer"}
posi.replace(chief, inplace=True)

chiefOperating = {"chief operations officer":"chief operating officer"}
posi.replace(chiefOperating, inplace=True) 

chef = {"junior chef":"chef","senior chef":"chef",}
posi.replace(chef, inplace=True)

claims = {"claims officer – health":"claims officer"}
posi.replace(claims, inplace=True)

clinical = {"clinical officer":"clinic officer"}
posi.replace(clinical, inplace=True)

client = {"intern client officers":"client officer"}
posi.replace(client, inplace=True)

communication = {"communications officer":"communication officer"}
posi.replace(communication, inplace=True)

conditionalSailed = {"conditional salaried financial advisor":"conditional sailed financial advisor"}
posi.replace(conditionalSailed, inplace=True) 

dataClerk = {"data entry clerk":"data clerk","data entry clerks":"data clerk"}
posi.replace(dataClerk, inplace=True) 

dataCollection = {"data collection officer":"data collector","data collectors(6)":"data collector"}
posi.replace(dataCollection, inplace=True)

dataOfficer = {"data officer  intern":"data officer",}
posi.replace(dataOfficer, inplace=True)

debtCo = {"temporally debt collectors":"debt collector","temporary debt collectors (50)":"debt collector",}
posi.replace(debtCo, inplace=True)

dg = {"director general(gd)":"director general",}
posi.replace(dg, inplace=True)

disease = {"disease control and surveillance assistants":"disease control and surveillance assistant",}
posi.replace(disease, inplace=True)

districtPro = {"district project officer(dop)":"district project officer",}
posi.replace(districtPro, inplace=True)

driver = {"4 drivers":"driver","school driver":"driver","truck drivers(2)":"driver","truck driver(2)":"driver","truck driver":"driver",
    "4x4 car drivers & 15 ton truck drivers":"driver","driver (4)":"driver","driver facilitators":"driver","driver (4 positions) - grade b2":"driver",
    "driver- logistician":"driver","drivers":"driver","‎driver (grade n)":"driver","car driver":"driver","concrete mixer driver":"driver",
    "project driver":"driver", "psv driver":"driver", "tractor drivers":"driver","motor vehicle driver":"driver",
}
 
posi.replace(driver, inplace=True) 

electrician = {"electricians":"electrician","electrical technician":"electrician"," electrical technician (2)":"electrician",}
posi.replace(electrician, inplace=True)

enumerators = {"enumerators (15 posts)":"enumerators",}
posi.replace(enumerators, inplace=True)

environmental = {"environment officcer":"environmental officer",}
posi.replace(environmental, inplace=True)

executive = {"executive assistant – strategy and business support":"executive assistant",}
posi.replace(executive, inplace=True)

fieldMar = {"field marketing representatives (6)":"field marketing representatives",}
posi.replace(fieldMar, inplace=True)

fieldOff = {"field officers ( 2)":"field officer","senior field officers":"field officer","field officers(2)":"field officer","field officers (three -agriculture and  livelihoods, gender and safeguarding and nutrition":"field officer",}
posi.replace(fieldOff, inplace=True)

foreman = {"foremen":"foreman",}
posi.replace(foreman, inplace=True)

graphic = {"graphic designer(2 posts)":"graphic designer","volunteer graphic designer":"graphic designer",}
posi.replace(graphic, inplace=True)

headteacher = {"headteacher":"head teacher","school headteacher":"head teacher"}
posi.replace(headteacher, inplace=True)

housekeeper = {"house keeper":"housekeeper",}
posi.replace(housekeeper, inplace=True) 

humanResource = {"hr intern":"human resource officer","hr officer":"human resource officer","senior hr officer":"human resource officer",}
posi.replace(humanResource, inplace=True) 

humanMan = {"hr manager":"human resource manager","human resource managers":"human resource manager","human resources intern":"human resource manager",
    "site human resource manager":"human resource manager",
}
posi.replace(humanMan, inplace=True) 

ictTec = {"ict technician officer":"ict technician",}
posi.replace(ictTec, inplace=True)
 
internal = {"internal audit":"internal auditor",}
posi.replace(internal, inplace=True)

lecture = {"lecture in early childhood development":"lecturer","lecturer in humana resource management and business management":"lecturer",
    "lecturers, assistant registrar, ict officer & corporate relations and marketing officer":"lecturer","lectures":"lecturer"," lecturers":"lecturer",
    "lecturers in accountancy":"lecturer","lectures and clinical instructor":"lecturer","pharmacy lectures (2 posts)":"lecturer",
    "senior lecturer":"lecturer","senior lectures":"lecturer",
}
posi.replace(lecture, inplace=True)

manager = {"manager director":"managing director",}
posi.replace(manager, inplace=True)

marketingAss = {"marketing assistant intern":"marketing assistant",}
posi.replace(marketingAss, inplace=True)

medicalOff = {"medical officers":"medical officer","senior medical officer":"medical officer",}
posi.replace(medicalOff, inplace=True) 

mentalHe = {"mental health clinical officer":"mental health clinician",}
posi.replace(mentalHe, inplace=True)
 
messenger = {"messengers":"messenger",}
posi.replace(messenger, inplace=True)

nurses = {"2 nurses":"nurse", "clinic nurse":"nurse", "mental health nurse":"nurse","clinic nurse (3)":"nurse","mental health nurse (2 posts)":"nurse",
    "specialized nurse":"nurse",
}
posi.replace(nurses, inplace=True)

officeAss = {"office assistant (2 posts)":"office assistant",}
posi.replace(officeAss, inplace=True) 

operations = {"operations director – school feeding programme":"operations director",}
posi.replace(operations, inplace=True)

operationsMan = {"operations manager (2 posts)":"operations manager",}
posi.replace(operationsMan, inplace=True)

personalAss = {"personal assistant to the executive director":"personal assistant",}
posi.replace(personalAss, inplace=True)

pharmacy = {"pharmacy technician (3)":"pharmacy technician",}
posi.replace(pharmacy, inplace=True)

plumber = {"part-time plumbers":"plumber","plumbers":"plumber","plumbing technician":"plumber",}
posi.replace(plumber, inplace=True)
 
primary = {"primary teacher":"primary school teacher","primary school teachers":"primary school teacher","primary teachers":"primary school teacher","primary teaching intern":"primary school teacher",}
posi.replace(primary, inplace=True)

procurementMan = {"procurement manager (network infrastructure, it and digital services)":"procurement manager", "procurement manager (indirect category)":"procurement manager",}
posi.replace(procurementMan, inplace=True)

procurementOff = {"procurement official":"procurement officer", "procurement officers":"procurement officer",}
posi.replace(procurementOff, inplace=True)

programmeOfficer = {"2 livelihood restoration programme officer":"program officer","program officers (2)":"program officer",
    "programme officer":"program officer","programme officer- financial inclusion":"program officer"
}
posi.replace(programmeOfficer, inplace=True)

projectCoo = {"project coordinator – health and nutrition":"project coordinator", "project coordinator(2 post)":"project coordinator",
    " project coordinator– agree malawi":"project coordinator"
}
posi.replace(projectCoo, inplace=True)

projectMan = {"project manage":"project manager",}
posi.replace(projectMan, inplace=True)

projectOff = {"project officer (3)":"project officer",}
posi.replace(projectOff, inplace=True)

projectCoo= {"projects coordinator":"project coordinator",}
posi.replace(projectCoo, inplace=True)
 
psychosocial = {"psychosocial counselor":"psychosocial counsellor",}
posi.replace(psychosocial, inplace=True) 

refrigeration = {"refrigeration technician (2)":"refrigeration technician",}
posi.replace(refrigeration, inplace=True)

regional = {"regional managers":"regional manager",}
posi.replace(regional, inplace=True)

research = {"temporary research assistants-qualitative (6 posts)":"research assistant","temporary research assistants (24 posts)":"research assistant","research assistants":"research assistant","research assistant-insectary(2 posts)":"research assistant",}
posi.replace(research, inplace=True) 
 
salesAgent = {"sales agents":"sales agent","commissioned sales agent":"sales agent",}
posi.replace(salesAgent, inplace=True)

salesExc= {"sales executives":"sales executive",}
posi.replace(salesExc, inplace=True)

salesRepre = {"sales representatives":"sales representative","sales representative(10-15 posts)":"sales representative",}
posi.replace(salesRepre, inplace=True) 

seasonal = {"seasonal worker (20)":"seasonal worker","seasonal workers(9)":"seasonal worker","seasonal worker (43)":"seasonal worker","seasonal worker (40)":"seasonal worker"}
posi.replace(seasonal, inplace=True)

security = {"security guards":"security guard","security guard (2 posts)":"security guard","guard":"security guard","temporary security guards (52)":"security guard",}
posi.replace(security, inplace=True)

store = {"stores clerk":"store clerk",}
posi.replace(store, inplace=True)

teacher = {"teacher's":"teacher","teachers":"teacher","teachers for languages":"teacher","computer teacher":"teacher","dramas teacher":"teacher",
    "secondary school teacher (physics and chemistry)":"teacher","secondary school teachers":"teacher","science teacher":"teacher","english teacher":"teacher",
    "french teacher":"teacher","kindergarten teacher":"teacher","language teacher":"teacher","passionate teachers":"teacher","positions various":"teacher",
    "preschool teachers":"teacher","primary & nursery school teachers":"teacher","primary teacher":"teacher","primary school teachers":"teacher",
    "primary teachers":"teacher","primary teaching intern":"teacher","primary school teacher":"teacher","secondary and primary school teachers":"teacher",
    "secondary school teacher":"teacher","send teachers":"teacher",
}
posi.replace(teacher, inplace=True)

team = {"deputy team leader – partnerships and programming":"team leader","team leader (production)":"team leader","team leader - revenue monitoring":"team leader","team leader- taxpayer accounts reconciliation":"team leader",}
posi.replace(team, inplace=True)

tied = {"tied sales agents(20)":"tied sales agent","tied sales agents (20 posts)":"tied sales agent",}
posi.replace(tied, inplace=True)
 
vice = {"vice-chancellor":"vice chancellor",}
posi.replace(vice, inplace=True)

count = 1
for position in posi.sort_values().unique():
    print(f"{count}. {position}")
    count+=1
# Out:
# 1. abattoir supervisor
# 2. academic support officer
# 3. account's manager
# 4. accountant
# 5. accountant and assistant accountant
# 6. accountant assistant
# 7. accountant executive
# 8. accountant manager
# 9. accounting associate
# 10. accounting officer
# 11. accounts
# 12. accounts and administration officer
# 13. accounts assistant
# 14. accounts manager
# 15. accounts officer
# 16. accounts payable associate
# 17. accounts relations officer
# 18. administration & logistics officer
# 19. administration & marketing assistant
# 20. administration & marketing assistants
# 21. administration and hr manager
# 22. administrative assistant
# 23. administrative officer
# 24. administrator
# 25. advisor for ohdaa
# 26. advisor(communication and private sector development)
# 27. agent & merchant coordinator
# 28. agribusiness officer
# 29. agribusiness specialist
# 30. agriculture and nutrition field officer
# 31. agriculture field officer (2)
# 32. agroforestry field supervisor
# 33. agronomist
# 34. air conditioning technician
# 35. airport developments limited
# 36. airport receptionist
# 37. anaesthesia clinic offer
# 38. aquaculture
# 39. area supervisor
# 40. artisan boilermaker
# 41. artisan electrician
# 42. artisan fitter
# 43. artisan mechanic
# 44. artisan turner
# 45. assets & liabilities management officer
# 46. assistant
# 47. assistant accountant
# 48. assistant administration and human resource officer
# 49. assistant administrative officer
# 50. assistant claims manager
# 51. assistant claims officer
# 52. assistant college registrar – academic
# 53. assistant company secretary
# 54. assistant finance manager
# 55. assistant finance officer
# 56. assistant for political, culture, and public relations section
# 57. assistant housekeeper
# 58. assistant human resource manager
# 59. assistant human resource officer
# 60. assistant internal auditor
# 61. assistant lines person (433)
# 62. assistant linesmen
# 63. assistant lodge manager
# 64. assistant logistics and supply chain officer
# 65. assistant manager
# 66. assistant monitoring and evaluation specialist
# 67. assistant monitoring officer
# 68. assistant procurement and assets disposal officer
# 69. assistant sales & marketing manager
# 70. assistant surveyor of vessels
# 71. assistant system support officer
# 72. assistant systems administrators
# 73. assistant water resources development officer
# 74. associate creative director
# 75. associates
# 76. audit manager
# 77. audit senior
# 78. audit supervisor
# 79. audit supervisors & managers
# 80. auto electrical technician
# 81. auto electricians
# 82. auto mechanic
# 83. back-end developer intern
# 84. banana plantation manager
# 85. banking centre manager
# 86. barman
# 87. bible knowledge teacher
# 88. billing assistant
# 89. biomed technician
# 90. biomedical engineer (5 posts)
# 91. biostatistician
# 92. board member
# 93. board of commissioners(4)
# 94. branch manager
# 95. branch manager &  branch supervisor
# 96. brand & marketing executive
# 97. brand manager
# 98. budgeting and forecasting accountant
# 99. business administrator
# 100. business and economics teacher
# 101. business banker
# 102. business development & engagements coordinator
# 103. business development & marketing manager
# 104. business development & partnerships intern
# 105. business development analyst
# 106. business development executive
# 107. business development internship
# 108. business development manager
# 109. business development officer
# 110. business incubation officer
# 111. business support and ambulance driver
# 112. business transformation manager
# 113. business, digital and data analyst
# 114. butchery, bakery, and kitchen team lead
# 115. call centre agent
# 116. cambridge primary teacher year 2
# 117. camp chef, housekeeper, barman & camp steward
# 118. campus directors
# 119. capital city branch manager
# 120. cargo porter
# 121. carpentry artisan
# 122. cashier
# 123. ccr operator
# 124. cctv operator
# 125. chef
# 126. chef and receptionist
# 127. chef | waiter/waitress | mixologist (bartender)
# 128. chefs / waiters / waitresses
# 129. chief executive officer
# 130. chief finance officer
# 131. chief media and digitalisation manager
# 132. chief of staff (human resource department)
# 133. chief operating officer
# 134. chinese-chichewa interpreters(4 posts)
# 135. christian outreach program coordinator
# 136. civic education officer
# 137. civil servants sales representative (4)
# 138. civil/ structural engineer
# 139. civil/irrigation engineer
# 140. claims assistant
# 141. claims manager
# 142. claims officer
# 143. clerk
# 144. client engagement officer
# 145. client officer
# 146. client service executive
# 147. client services supervisor
# 148. client solutions officer
# 149. climate health lead
# 150. clinic attendant
# 151. clinic instructor
# 152. clinic officer
# 153. clinician
# 154. cluster manager for key retail business units
# 155. cmms data steward
# 156. collection officer
# 157. college principal
# 158. commercial airline pilot - captain
# 159. commercial airline pilot - first officer
# 160. commission revenue collectors (10)
# 161. commissionaire
# 162. communication and multimedia officer
# 163. communication intern
# 164. communication officer
# 165. communication/entrepreneurship instructor
# 166. communications & admin intern
# 167. communications and advocacy manager
# 168. communications and marketing officer
# 169. communications specialist
# 170. communications, fundraising & partnerships manager
# 171. community liaison officers (2 posts)
# 172. community mobilisation
# 173. community-based program intern
# 174. company secretarial and head  of administration
# 175. compesation & benefits manager
# 176. compliance manager
# 177. compliance support workers
# 178. conditional sailed financial advisor
# 179. conference  writer
# 180. construction supervisor
# 181. consumer lending team leader
# 182. consumer sales executive (25)
# 183. contact center & social media
# 184. content creators
# 185. contracts manager
# 186. cook
# 187. corporate financial advisor
# 188. corporate social responsibility specialist
# 189. corporation relationship manager
# 190. cost control manager
# 191. counter sales clerk
# 192. country director
# 193. country manager
# 194. country managing director
# 195. credit & investment officer / loan officer
# 196. credit analysis officer
# 197. credit officer
# 198. customer care clerk
# 199. customer experience consultant
# 200. customer experience manager
# 201. customer service assistant
# 202. customer support officer
# 203. daeyang luke hospital
# 204. daily worker drivers
# 205. data center engineer
# 206. data champion
# 207. data clerk
# 208. data collector
# 209. data management consultancy
# 210. data officer
# 211. data officer / office assistant intern
# 212. deal origination & investment specialist
# 213. debit collector
# 214. debt collector
# 215. debtors clerk
# 216. dental therapist
# 217. dentist
# 218. dentists and dental therapists
# 219. depot supervisor
# 220. deputy auditor general
# 221. deputy director internal affairs
# 222. deputy head teacher (3 posts)
# 223. deputy vice-chancellor
# 224. diesel mechanics
# 225. digital marketing and sales
# 226. digital marketing intern
# 227. digital media & technology specialist
# 228. digital solutions
# 229. director - macroeconomic management programme
# 230. director general
# 231. director of corporate services
# 232. director of finance and administration
# 233. director of government partnerships
# 234. director of human resources management and administration
# 235. director of operations/project manager
# 236. director of postal services
# 237. director of program and development
# 238. disease control and surveillance assistant
# 239. dispensing supervisor
# 240. distribution team leader
# 241. district engineer
# 242. district managers
# 243. district project officer
# 244. division manager
# 245. dog handler
# 246. driver
# 247. driver, cleaner & occupational health & nurse
# 248. driver/office messenger
# 249. drop-in centre manager (clinician/nurse)
# 250. e-control enforcement assistant
# 251. economist
# 252. education officer
# 253. electrical engineer
# 254. electrical technician (2)
# 255. electrician
# 256. enumerators
# 257. environmental and social development specialist
# 258. environmental and social officer
# 259. environmental health
# 260. environmental officer
# 261. environmental safeguards specialist
# 262. environmental, health and safety specialist
# 263. event planner
# 264. excavator operator
# 265. executive assistant
# 266. executive director
# 267. executive secretary
# 268. export manager
# 269. extension agent
# 270. extension coordinator
# 271. extruder machine operator
# 272. facilities assistant
# 273. farm field supervisor
# 274. farm manager
# 275. farm mechanic
# 276. female journalist
# 277. female news reporter/radio presenter
# 278. field assistants
# 279. field coordinator
# 280. field epidemiology training program (fetp) resident advisor
# 281. field marketing representatives
# 282. field officer
# 283. field sales executive
# 284. field sites administrator
# 285. finance & admin officer
# 286. finance & administration assistant
# 287. finance & administration manager
# 288. finance & administration officer
# 289. finance & compliance officer
# 290. finance accountant officer
# 291. finance and administration assista
# 292. finance and administration officer
# 293. finance and administrative
# 294. finance and administrative assistant
# 295. finance and administrative coordinator
# 296. finance and administrative manager
# 297. finance associate
# 298. finance intern
# 299. finance manager
# 300. finance officer
# 301. finance officer- social marketing
# 302. financial advisory services specialist
# 303. financial controller
# 304. financial management specialist
# 305. financial planning & reporting associate
# 306. financial reporting accountant
# 307. financing specialist
# 308. fitter
# 309. fleet & administration manager
# 310. fmcg warehouse supervisor
# 311. food & beverage controller
# 312. food nutritionist
# 313. foreman
# 314. front desk and visitor officer
# 315. front desk coordinator
# 316. front desk officers
# 317. front desk receptionist
# 318. front office manager
# 319. front office officer
# 320. front office receptionist
# 321. front office supervisor
# 322. front office/receptionist
# 323. front office/receptionist assistant
# 324. front-end developer intern
# 325. fuel station attendants
# 326. fundraising & grants officer
# 327. fundraising finance manager
# 328. gaming machine operator
# 329. general foreman
# 330. general manager
# 331. gis & operations support technician
# 332. glamorous looks
# 333. goat farm manager
# 334. graduate engineers (grade range p3-p1)
# 335. graduate intern
# 336. grants and administration officer
# 337. grants officer
# 338. grants writer
# 339. graphic & brand designer
# 340. graphic designer
# 341. graphic designer and operations officer
# 342. green leaf services logistics manager
# 343. ground labourer
# 344. group head of marketing & customer experience
# 345. group head of safety
# 346. group l & d manager
# 347. group management
# 348. head chef
# 349. head of business development
# 350. head of cash solutions
# 351. head of department – science
# 352. head of marketing, branding and communications
# 353. head of operations
# 354. head of recruitment
# 355. head of risk
# 356. head of sales
# 357. head of security
# 358. head teacher
# 359. head teacher and primary school teachers
# 360. head teacher, teachers and others
# 361. head-retail
# 362. headteacher, depurty headteacher & teachers
# 363. health and safety officer
# 364. health sciences tutor
# 365. health surveillance assistant
# 366. health workers
# 367. health, safety, security and environment (hsse) officer
# 368. hiv testing diagnostics assistants
# 369. hiv testing provider (hda)
# 370. holy family catholic secondary school
# 371. horticulture farm manager
# 372. hospital administrator
# 373. hospital attendant
# 374. housekeeper
# 375. hr & administration clerks
# 376. hr business partner and administration manager
# 377. human resource (hr) & administration officer
# 378. human resource and admin officer
# 379. human resource and administration officer
# 380. human resource manager
# 381. human resource officer
# 382. human resource supervisor
# 383. human resources & administration manager
# 384. human resources & administration officer
# 385. human resources & business mentor
# 386. human resources and administration manager
# 387. human resources and administration officer
# 388. human resources and administration officer (hrao)
# 389. human resources association
# 390. human resources manager
# 391. human resources officer
# 392. human resources operations officer
# 393. i.t. systems auditor | driver.
# 394. ict (systems administrator)
# 395. ict and communications officer
# 396. ict development officer
# 397. ict instructor
# 398. ict officer
# 399. ict systems assistant
# 400. ict technician
# 401. icu unit manager
# 402. immigration recruit
# 403. immunization specialist
# 404. impact officer
# 405. index insurance specialist
# 406. induction officer
# 407. informal waste worker (iww) coordination
# 408. information officer
# 409. information technology specialist
# 410. infrastructure officer-civil
# 411. instructor in tailoring and fashion design
# 412. insurance claims officer
# 413. insurance underwriting officer
# 414. integral mission project officer
# 415. interface and electrical manager
# 416. intern
# 417. internal audit manager
# 418. internal audit officer
# 419. internal audit specialist
# 420. internal auditor
# 421. internal compliance assistant / general services assistant
# 422. internal controls officer
# 423. interns for non- communicable diseases (ncd) project
# 424. inventory controller
# 425. investigations officer
# 426. investment banking manager – corporate securitisations
# 427. it manager
# 428. it officer
# 429. it specialist
# 430. junior cabin crew
# 431. junior engineer/site agent
# 432. junior monitoring & evaluation specialist
# 433. junior software engineer
# 434. junior technical advisor
# 435. lab assistant
# 436. laboratory technician
# 437. laboratory technologist
# 438. land & construction (intern)
# 439. land surveyor
# 440. language and cross culture facilitator (lcf) / homestay and housing coordinator (hhc)
# 441. lawyer
# 442. leaf planning and analysis manager
# 443. lecturer
# 444. lecturers
# 445. legal advisor / company secretary
# 446. legal affairs manager
# 447. legal counsel
# 448. legal intern
# 449. legal services manager
# 450. librarian
# 451. library assistant
# 452. livestock attendant
# 453. loan officer
# 454. lodge manager
# 455. lodge receptionist
# 456. logistics manager
# 457. logistics systems clerk
# 458. loss control officer
# 459. lpg gas station attendant
# 460. m&e assistants (3)
# 461. macadamia manager.
# 462. maintainance officer
# 463. malawi administration lead
# 464. malawi agroforestry associate
# 465. malawi sun hotel
# 466. malawi wash coordinator
# 467. male receptionist/messenger
# 468. management accountant
# 469. management trainees
# 470. manager marketing communications c2
# 471. managing director
# 472. marketing & communications manager
# 473. marketing & communications officer
# 474. marketing & communications officer (internship)
# 475. marketing and administrative officer
# 476. marketing and communication manager
# 477. marketing assistant
# 478. marketing consultants
# 479. marketing executive
# 480. marketing manager
# 481. marketing officer
# 482. marketing officer & farm attendant
# 483. marketing strategies & data analyst
# 484. marketing, media and communications officer
# 485. marketing/sales agents
# 486. materials engineer
# 487. maternal and neonatal nurse
# 488. mathematics teacher
# 489. meal officer
# 490. mechanical foreman
# 491. media and communications officer
# 492. media officer(intern)
# 493. medical assistant
# 494. medical doctor
# 495. medical manager
# 496. medical officer
# 497. medicines inspection officer
# 498. mental health clinician
# 499. mental health lead
# 500. messenger
# 501. messenger & cleaner
# 502. micgbv secretariat coordinator
# 503. microbiologist
# 504. middle class & reception class teachers
# 505. midwife educators
# 506. ministry of natural resources and climate change
# 507. mlearn development facilitator
# 508. mobile supervisor
# 509. monitoring & evaluation (m&e) manager
# 510. monitoring & evaluation assistant
# 511. monitoring and evaluation (m&e) officer
# 512. monitoring and evaluation officer
# 513. monitoring and evaluation specialist
# 514. monitoring, evaluation, accountability and learning (meal) officer
# 515. monitoring, evaluation, research and learning officer
# 516. mortician
# 517. motor vehicle technicians
# 518. national coordinator
# 519. national director
# 520. non-executive directors
# 521. nurse
# 522. nurse and midwife
# 523. nurse midwife
# 524. nurse midwife technician
# 525. nurse officer
# 526. nurse service provider
# 527. nursery school teachers
# 528. nursing officer
# 529. occupational health and safety officer
# 530. office administrator (seasonal)
# 531. office assistant
# 532. office assistant & driver
# 533. office cleaner
# 534. office receptionist/office cleaner
# 535. officer cadets
# 536. one-stop service centre (ossc) digital services officer
# 537. open efficiency officer
# 538. operating and fees reconciliation officer
# 539. operations & admin assistant
# 540. operations clerk
# 541. operations coordinator
# 542. operations director
# 543. operations manager
# 544. operations support agent- associate
# 545. operations support manager
# 546. optometric technician
# 547. ore spotter
# 548. painter
# 549. paralegal
# 550. parks and wildlife assistant
# 551. partnership & philanthropy intern
# 552. partnerships and advocacy manager
# 553. partnerships and sales officer
# 554. patients attendant
# 555. pension services officer
# 556. people operations administrator
# 557. personal assistant
# 558. personal assistant/driver to the ceo
# 559. pharmacist
# 560. pharmacy assistant
# 561. pharmacy assistant/technician
# 562. pharmacy technician
# 563. photographer & videographer
# 564. physical therapist
# 565. pine tree planting project coordinator
# 566. planning engineer
# 567. plumber
# 568. porter
# 569. portfolio manager
# 570. post paid & enterprise administrator
# 571. postdoctoral researcher
# 572. pr and corporate affairs manager & presales manager
# 573. pre-school teacher
# 574. precision agriculture specialist
# 575. prepaid billing administrator
# 576. presenter
# 577. presenter/ producer
# 578. pricing officer
# 579. primary head teacher & class teachers
# 580. primary school head teacher
# 581. primary school teacher & assistant
# 582. principal
# 583. principal (vocational school)
# 584. principal accountabilities and responsibilities
# 585. principal accreditation
# 586. principal corporate affairs and public relations officer
# 587. principal hospital administrator
# 588. principal investigations officer
# 589. principal law reform officer
# 590. principal procurement officer
# 591. principal registration and compliance officer
# 592. principle officer
# 593. printing & graphic designer
# 594. prison warder/wardress
# 595. private beach administrator
# 596. process interns
# 597. process server
# 598. process server/messenger
# 599. processing technical superintendent
# 600. procurement & contract officer
# 601. procurement & logistics manager
# 602. procurement and logistics
# 603. procurement expert
# 604. procurement manager
# 605. procurement officer
# 606. procurement specialist
# 607. product development
# 608. product support manager
# 609. production & sales officer
# 610. production manager
# 611. professional teachers
# 612. program & administrative officer
# 613. program assistant
# 614. program coordinator
# 615. program implementers (5 posts)
# 616. program manager
# 617. program officer
# 618. program sanitation officer
# 619. programme associate for women economic empowerment
# 620. programme coordinator – fighting inequality
# 621. programme manager
# 622. programme specialist for elimination of violence against women and girls
# 623. programs & fundraising officer
# 624. programs director
# 625. programs officer
# 626. project administrative assistant
# 627. project administrator
# 628. project coordinator
# 629. project coordinator– agree malawi
# 630. project hr officer
# 631. project manager
# 632. project manager and marketing manager
# 633. project officer
# 634. project officer intern & finance and admin
# 635. project procurement & logistics officer
# 636. project stores clerk-save project
# 637. projects engineer/site agent
# 638. projects manager (civil engineer)
# 639. projects officer - civil (2)
# 640. property officer (valuation)
# 641. property officer(valuation)
# 642. protection project manager
# 643. psychosocial counsellor
# 644. public and environment health manager
# 645. public education officers (2)
# 646. public engagement manager
# 647. public health assistant
# 648. public relations manager & personal assistant to the gdhl president
# 649. public relations officer
# 650. purchase officer
# 651. qualitative research assistant
# 652. quality assurance / quality control lead
# 653. quality assurance officer
# 654. quality control analyst
# 655. quality controller
# 656. quantity surveyor
# 657. quantity surveyor and sherq officer
# 658. radio producer and reporter
# 659. radiography technician
# 660. ran operations engineer (3 posts)
# 661. react or nextjs developers
# 662. receivable reconciliation assistant
# 663. receptionist
# 664. receptionist,  administrative assistant & office assistant/ messenger
# 665. recruiting volunteers
# 666. refrigeration technician
# 667. regional environment and climate change officer
# 668. regional manager
# 669. regional project coordinator
# 670. regional security manager
# 671. regionals sales manager
# 672. registration and licensing manager
# 673. registration and licensing officer
# 674. regulatory & compliance manager
# 675. reinsurance officer
# 676. relations assistants
# 677. relationship analyst
# 678. relationship manager
# 679. remote sales officers (2)  & remote collections officers (2)
# 680. rental development executive
# 681. reporters(4 posts)
# 682. reporting clerk intern
# 683. research and administration
# 684. research assistant
# 685. research associate
# 686. research centre manager
# 687. research governance officer
# 688. research manager
# 689. reservations executive
# 690. resilient agriculture senior manager
# 691. resort supervisor
# 692. resource mobilisation consultant
# 693. resource mobilization officer
# 694. restaurant manager
# 695. retail development executive
# 696. risk & compliance officer
# 697. risk analyst
# 698. risk and compliance officer
# 699. safety health and training officer
# 700. sakes & business development manager
# 701. sales & marketing officer
# 702. sales & marketing representatives(3 posts)
# 703. sales accountant
# 704. sales administrator
# 705. sales agent
# 706. sales agronomists
# 707. sales and digital marketer
# 708. sales and marketing executive
# 709. sales and marketing executives
# 710. sales and marketing manager
# 711. sales and marketing office
# 712. sales and marketing officer
# 713. sales and marketing representative
# 714. sales and ticketing agent
# 715. sales assistant
# 716. sales clerk
# 717. sales consultant
# 718. sales coordinators
# 719. sales executive
# 720. sales lead
# 721. sales manager
# 722. sales marketing executives
# 723. sales officer
# 724. sales representative
# 725. sales supervisor
# 726. sales, floor & administration officer
# 727. sales, floor and administration officer
# 728. school administrator
# 729. school administrator/school principal
# 730. school bursar
# 731. school feeding specialist
# 732. scientific administrator
# 733. seasonal cleaners (19)
# 734. seasonal worker
# 735. secondary school secretary
# 736. secretary
# 737. security coordinator
# 738. security guard
# 739. security guards & labourers
# 740. security officer
# 741. security officers/guards (1645 posts)
# 742. security supervisor
# 743. senior accountant/accountant
# 744. senior accounts administrators
# 745. senior accounts officer
# 746. senior administrative officer
# 747. senior agriculture commercialization specialist
# 748. senior audit manager
# 749. senior corporate relationship manager
# 750. senior credit & investments officer
# 751. senior engineer
# 752. senior finance and administration manager
# 753. senior finance manager, malaria & neglected tropical diseases (mntd), reach malaria
# 754. senior finance officer
# 755. senior hospital administrator
# 756. senior lead – hr operations
# 757. senior nursing officer
# 758. senior opthalmic clinical technician
# 759. senior orthopedic therapist
# 760. senior programe manager
# 761. senior quantity surveyor
# 762. senior reservations consultant
# 763. senior sales coordinator (3 posts)
# 764. senior specialist financial investigations
# 765. service centre manager
# 766. service management officer
# 767. sherq system specialist
# 768. shop admin officer & ict repair technician
# 769. shop manager
# 770. site administrator
# 771. site agent
# 772. site engineer
# 773. site quality assurance/ quality control inspector
# 774. site supervisors (multiple positions)
# 775. skills center manager
# 776. sme sales representatives(2
# 777. social and gender specialist
# 778. social educator
# 779. social health and environmental officer
# 780. social media lead
# 781. social media manager
# 782. social media officer
# 783. social media specialist
# 784. social safeguards specialist
# 785. social workers(2)
# 786. software business analyst/quality assurance officer
# 787. software developer
# 788. software development and operations (devops) engineer
# 789. solar / electrical technician
# 790. special needs teacher
# 791. specialist consultant - marketing and communications
# 792. specialist, corruption prevention
# 793. statistician/epidemiologist
# 794. steam & power generation engineer
# 795. store & business development manager
# 796. store clerk
# 797. stores and accounts clerk
# 798. stores and logistics associate
# 799. stores assistant
# 800. student recruitment, pr and university placement officer
# 801. study coordinator
# 802. substations control technicians(3)
# 803. supervisor
# 804. supply chain officer
# 805. sustainable tobacco production monitor
# 806. system engineer
# 807. systems administrators
# 808. systems developer
# 809. systems technician
# 810. tailor, welder & carpenter
# 811. tax accountant
# 812. teacher
# 813. teacher & matron
# 814. teacher's & sheikh
# 815. teachers & headteacher
# 816. team leader
# 817. technical advisor
# 818. technical coordinator
# 819. technical officer
# 820. technician
# 821. technician implementation support brokers
# 822. technology and systems officer
# 823. temporary archive assistant
# 824. temporary benefits administration clerk
# 825. temporary debt collection assistants (80 posts)
# 826. temporary facility and dhis2 data review officers (12 posts)
# 827. temporary finance & compliance officer
# 828. temporary horticulture supervisor
# 829. temporary presiding officer
# 830. temporary registration assistant
# 831. temporary registration assistant.
# 832. temporary sponsorship assistant
# 833. temporary water monitoring assistant
# 834. territory manager
# 835. territory sales officers
# 836. the executive assistant officer
# 837. the marketing and partnership officer
# 838. tied sales agent
# 839. till operators
# 840. tipper drivers & excavator operators
# 841. tourism manager
# 842. trainee business manager
# 843. trainee civil engineers
# 844. trainee data entry clerk
# 845. training manager
# 846. training officer
# 847. trauma counsellor
# 848. trutee
# 849. tyre fitter
# 850. undefined
# 851. underwriting assistant
# 852. underwriting manager
# 853. university graduates
# 854. user support officer
# 855. valuation advisory and brokerage officer
# 856. valuation,  advisory and brokerage officer
# 857. value chain development officers
# 858. vice chancellor
# 859. video producer
# 860. volunteer facilitators(6)
# 861. waiter
# 862. waiter or waitress
# 863. waiter, chef & housekeeper
# 864. waiter/waitress
# 865. warehouse assistant
# 866. warehouse supervisor
# 867. wash & climate resilience project manager
# 868. wash project officer
# 869. water security facilitator
# 870. welder
# 871. workshop manager
# 872. workshop supervisor
# 873. workshop/ garage manager
# 874. world vision board member
# 875. writers
# 876. zonal business manager
